-- %%
USE CATALOG WORKSPACE;
SHOW SCHEMAS;
USE SCHEMA salesdb;
SHOW TABLES;
SELECT 
category,
subcategory,
product_name
FROM dim_products


--Here are the tables in the current editor:
--Table name: WORKSPACE.salesdb.dim_products
